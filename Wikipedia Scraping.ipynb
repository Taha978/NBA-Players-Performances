# %% [markdown]
# #### Importing Libraries

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains
import json
import time
from time import sleep
import random
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the NBA Players' Names Data

# %%
with open('NBA Players.json','r') as file:
    data=json.load(file)
players=data['NBA Player']
# We check that the players list does not contain duplicate values 
players==list(dict.fromkeys(players))
#True means that our list contains only unique values
# Out:
# True

# %% [markdown]
# #### Initialize a Chrome Session

# %%
driver=webdriver.Edge(executable_path='C:\\Users\\TAHA\\Webdriver_taha\\msedgedriver.exe')
time.sleep(random.randint(3,6))
driver.get('https://fr.wikipedia.org/wiki/Wikip%C3%A9dia:Accueil_principal')

# %% [markdown]
# #### Scraping Functions

# %%
# This function locates the search bar and types the player's name
# then simulates an enter key to laod the player's wikipedia page
def search_player(driver,player):
    time.sleep(1)
    driver.find_element(By.CLASS_NAME,'vector-header-end').find_element(By.ID,'p-search').find_element(By.TAG_NAME,'a').click()
    time.sleep(1)
    search_bar=driver.find_element(By.CLASS_NAME,'vector-typeahead-search-container').find_element(By.CLASS_NAME,'cdx-text-input__input')
    time.sleep(1)
    search_bar.send_keys(player)
    time.sleep(1)
    search_bar=driver.find_element(By.CLASS_NAME,'vector-typeahead-search-container').find_element(By.CLASS_NAME,'cdx-text-input__input')
    driver.find_element(By.ID,'searchform').find_element(By.TAG_NAME,'button').click()
    time.sleep(1)

# %%
# This function checks whether a table corresponds 
# to a player's statistics table or not 
def table_check(elem):
    headers=elem.find_elements(By.TAG_NAME,'th')
    try:
        if headers[0].text.replace(' ','')=='Saison' and headers[1].text.replace(' ','')=='Équipe' and headers[2].text.replace(' ','')=='MJ':
            return True
        else:
            return False
    except:
        return False
## Typically, the rows of a table that contains performance data follow this pattern: Saison, Équope, MJ (Match Player)
# We will use this pattern to identify those tables

# %%
# This function retrieves performance data for each player and creates a list of dictionaries as output
def retrieve_data_from_table(performance_tables):
    player_performance_data=[]
    dict={}
    for elem in performance_tables:
        try:
            headers=elem.find_elements(By.TAG_NAME,'th')
            headers=[elem.text.replace(' ','') for elem in headers][2:]# We rule out the first two headers which are Saison and Equipe as they do not correspond to any data
            #Some notable players have an all-star game performance row that appears as the last row right below the career perforamnce row, while others have the career performacne
            #row as the last row. Since we are only interested in the career row, we apply the following condition that takes into account these case scenarios. 
            # If a player has an all-star game row, we take the row that's above it
            if elem.find_element(By.TAG_NAME,'tbody').find_elements(By.TAG_NAME,'tr')[-1].find_element(By.TAG_NAME,'td').text.replace(' ','')=='All-Star Game':
                table_data=elem.find_element(By.TAG_NAME,'tbody').find_elements(By.TAG_NAME,'tr')[-2].find_elements(By.TAG_NAME,'td')[1:] 
            else:
                table_data=elem.find_element(By.TAG_NAME,'tbody').find_elements(By.TAG_NAME,'tr')[-1].find_elements(By.TAG_NAME,'td')[1:]
            # We take the last row that contains the data and remove the first header "Carrière"
            table_data=[elem.text.replace(' ','') for elem in table_data if not any(char.isalpha() for char in elem.text)]
            dict={headers[i]:table_data[i] for i in range(len(headers))}
            player_performance_data.append(dict)
            print('Data successfully retrieved')
        except:
            print('Error while retrieving data')
            player_performance_data.append(dict)
    return player_performance_data

# %% [markdown]
# #### Data Scraping

# %%
#Initialize the data dictionary to empty
player_data_dict={}
i=0
# Run the scraping algorithm through the entire list of players
for player in players:
    try:
        i=i+1
        #Searching the player on wikipedia
        print('Player number ',i,': ',player)
        try:
            search_player(driver,player)
            #We locate the performance tables in the wikipedia page
            container=driver.find_element(By.CLASS_NAME,'mw-page-container').find_element(By.CLASS_NAME,'mw-content-container').find_element(By.CLASS_NAME,'mw-body')
            tables=container.find_elements(By.TAG_NAME,'table')
            driver.find_element(By.ID,'Statistiques') # When the page does not contain a statistics section, this means that the right page was not loaded.
            #Therefore, we add (Basketball) after the player's name in the search form
        except:
            try:
                search_player(driver,player+' (Basketball)')
                #We locate the performance tables in the wikipedia page
                container=driver.find_element(By.CLASS_NAME,'mw-page-container').find_element(By.CLASS_NAME,'mw-content-container').find_element(By.CLASS_NAME,'mw-body')
                tables=container.find_elements(By.TAG_NAME,'table')
                driver.find_element(By.ID,'Statistiques')
            except:
                print('Error during the search phase')
        time.sleep(random.randint(2,4))

        try:
            performance_tables=[elem for elem in tables if table_check(elem)==True]
        except:
            print('Error while locating the performance tables')
        # Retrieve the performance data from the wikipedia page
        player_data_dict[player]=retrieve_data_from_table(performance_tables)
        print('##########################################')
        time.sleep(random.randint(3,5))
    except:
        print('Error while inserting data for player: ',player)
        print('##########################################')
        player_data_dict[player]=[]
        time.sleep(random.randint(3,5))
# Out:
# Player number  1 :  Precious Achiuwa
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  2 :  Steven Adams
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  3 :  Bam Adebayo
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  4 :  Ochai Agbaji
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  5 :  James Akinjo
# Error during the search phase
# ##########################################
# Player number  6 :  Santi Aldama
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  7 :  Trey Alexander
# Error during the search phase
# ##########################################
# Player number  8 :  Nickeil Alexander-Walker
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  9 :  Grayson Allen
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  10 :  Jarrett Allen
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  11 :  Jose Alvarado
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  12 :  Kyle Anderson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  13 :  Giannis Antetokounmpo
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  14 :  Cole Anthony
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  15 :  OG Anunoby
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  16 :  Mark Armstrong
# Error during the search phase
# ##########################################
# Player number  17 :  Deni Avdija
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  18 :  Deandre Ayton
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  19 :  Armando Bacot
# Error during the search phase
# ##########################################
# Player number  20 :  Marvin Bagley III
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  21 :  Amari Bailey
# Data successfully retrieved
# ##########################################
# Player number  22 :  Robert Baker
# Error during the search phase
# ##########################################
# Player number  23 :  Patrick Baldwin Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  24 :  LaMelo Ball
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  25 :  Lonzo Ball
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  26 :  Mo Bamba
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  27 :  Paolo Banchero
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  28 :  Desmond Bane
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  29 :  Dalano Banton
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  30 :  Dominick Barlow
# ##########################################
# Player number  31 :  Harrison Barnes
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  32 :  Scottie Barnes
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  33 :  RJ Barrett
# Error during the search phase
# ##########################################
# Player number  34 :  Charles Bassey
# Data successfully retrieved
# ##########################################
# Player number  35 :  Emoni Bates
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  36 :  Keita Bates-Diop
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  37 :  Jamison Battle
# Error during the search phase
# ##########################################
# Player number  38 :  Nicolas Batum
# Error during the search phase
# ##########################################
# Player number  39 :  Bradley Beal
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  40 :  Malik Beasley
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  41 :  MarJon Beauchamp
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  42 :  Charles Bediako
# Data successfully retrieved
# ##########################################
# Player number  43 :  Reece Beekman
# Data successfully retrieved
# ##########################################
# Player number  44 :  Jules Bernard
# Error during the search phase
# ##########################################
# Player number  45 :  Saddiq Bey
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  46 :  Goga Bitadze
# Data successfully retrieved
# ##########################################
# Player number  47 :  Onuralp Bitim
# ##########################################
# Player number  48 :  Anthony Black
# Data successfully retrieved
# ##########################################
# Player number  49 :  Bogdan Bogdanović
# Error during the search phase
# ##########################################
# Player number  50 :  Bojan Bogdanović
# Error during the search phase
# ##########################################
# Player number  51 :  Bol Bol
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  52 :  Adem Bona
# Data successfully retrieved
# ##########################################
# Player number  53 :  Devin Booker
# Error during the search phase
# ##########################################
# Player number  54 :  Brandon Boston Jr.
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  55 :  Chris Boucher
# Error during the search phase
# ##########################################
# Player number  56 :  Malaki Branham
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  57 :  Christian Braun
# Data successfully retrieved
# ##########################################
# Player number  58 :  Jalen Bridges
# Data successfully retrieved
# ##########################################
# Player number  59 :  Mikal Bridges
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  60 :  Miles Bridges
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  61 :  Malcolm Brogdon
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  62 :  Dillon Brooks
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  63 :  Keion Brooks Jr.
# Error during the search phase
# ##########################################
# Player number  64 :  Bruce Brown
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  65 :  Jaylen Brown
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  66 :  Kendall Brown
# Data successfully retrieved
# ##########################################
# Player number  67 :  Kobe Brown
# Data successfully retrieved
# ##########################################
# Player number  68 :  Charlie Brown Jr.
# Error during the search phase
# ##########################################
# Player number  69 :  Jalen Brunson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  70 :  Thomas Bryant
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  71 :  Kobe Bufkin
# Data successfully retrieved
# ##########################################
# Player number  72 :  Alec Burks
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  73 :  Jared Butler
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  74 :  Jimmy Butler
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  75 :  Matas Buzelis
# Data successfully retrieved
# ##########################################
# Player number  76 :  Jamal Cain
# ##########################################
# Player number  77 :  Kentavious Caldwell-Pope
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  78 :  Toumani Camara
# Data successfully retrieved
# ##########################################
# Player number  79 :  Vlatko Čančar
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  80 :  Clint Capela
# Error during the search phase
# ##########################################
# Player number  81 :  Branden Carlson
# Data successfully retrieved
# ##########################################
# Player number  82 :  Carlton Carrington
# Data successfully retrieved
# ##########################################
# Player number  83 :  Devin Carter
# Data successfully retrieved
# ##########################################
# Player number  84 :  Jevon Carter
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  85 :  Wendell Carter Jr.
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  86 :  D.J. Carton
# Error during the search phase
# ##########################################
# Player number  87 :  Alex Caruso
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  88 :  Stephon Castle
# Data successfully retrieved
# ##########################################
# Player number  89 :  Colin Castleton
# Data successfully retrieved
# ##########################################
# Player number  90 :  Julian Champagnie
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  91 :  Justin Champagnie
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  92 :  Ulrich Chomche
# Error during the search phase
# ##########################################
# Player number  93 :  Cam Christie
# Data successfully retrieved
# ##########################################
# Player number  94 :  Max Christie
# Data successfully retrieved
# ##########################################
# Player number  95 :  Josh Christopher
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  96 :  Sidy Cissoko
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  97 :  Jaylen Clark
# Data successfully retrieved
# ##########################################
# Player number  98 :  Brandon Clarke
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  99 :  Jordan Clarkson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  100 :  Nic Claxton
# Error during the search phase
# ##########################################
# Player number  101 :  Donovan Clingan
# Data successfully retrieved
# ##########################################
# Player number  102 :  Noah Clowney
# Data successfully retrieved
# ##########################################
# Player number  103 :  Amir Coffey
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  104 :  Isaiah Collier
# Data successfully retrieved
# ##########################################
# Player number  105 :  John Collins
# Error during the search phase
# ##########################################
# Player number  106 :  Zach Collins
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  107 :  Mike Conley
# Error during the search phase
# ##########################################
# Player number  108 :  Pat Connaughton
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  109 :  Bilal Coulibaly
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  110 :  Ricky Council IV
# Data successfully retrieved
# ##########################################
# Player number  111 :  Torrey Craig
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  112 :  Isaiah Crawford
# Data successfully retrieved
# ##########################################
# Player number  113 :  Jalen Crutcher
# Data successfully retrieved
# ##########################################
# Player number  114 :  Jarrett Culver
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  115 :  Cade Cunningham
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  116 :  Seth Curry
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  117 :  Stephen Curry
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  118 :  Tristan da Silva
# Data successfully retrieved
# ##########################################
# Player number  119 :  Pacôme Dadiet
# Error during the search phase
# ##########################################
# Player number  120 :  Dyson Daniels
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  121 :  N'Faly Dante
# Data successfully retrieved
# ##########################################
# Player number  122 :  Anthony Davis
# Error during the search phase
# ##########################################
# Player number  123 :  Johnny Davis
# Error during the search phase
# ##########################################
# Player number  124 :  Terence Davis
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  125 :  JD Davison
# Data successfully retrieved
# ##########################################
# Player number  126 :  DeMar DeRozan
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  127 :  Moussa Diabaté
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  128 :  Mamadi Diakite
# Error during the search phase
# ##########################################
# Player number  129 :  Gradey Dick
# Data successfully retrieved
# ##########################################
# Player number  130 :  Ousmane Dieng
# Data successfully retrieved
# ##########################################
# Player number  131 :  Rob Dillingham
# Data successfully retrieved
# ##########################################
# Player number  132 :  Spencer Dinwiddie
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  133 :  Donte DiVincenzo
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  134 :  Luka Dončić
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  135 :  Luguentz Dort
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  136 :  Ayo Dosunmu
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  137 :  Jeff Dowtin Jr.
# Error during the search phase
# ##########################################
# Player number  138 :  PJ Dozier
# Error during the search phase
# ##########################################
# Player number  139 :  Andre Drummond
# ##########################################
# Player number  140 :  Chris Duarte
# Error during the search phase
# ##########################################
# Player number  141 :  Alex Ducas
# Data successfully retrieved
# ##########################################
# Player number  142 :  David Duke Jr.
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  143 :  Kris Dunn
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  144 :  Ryan Dunn
# Error during the search phase
# ##########################################
# Player number  145 :  Kevin Durant
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  146 :  Jalen Duren
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  147 :  Tari Eason
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  148 :  Zach Edey
# Data successfully retrieved
# ##########################################
# Player number  149 :  Anthony Edwards
# Error during the search phase
# ##########################################
# Player number  150 :  Jesse Edwards
# Data successfully retrieved
# ##########################################
# Player number  151 :  Justin Edwards
# Error during the search phase
# ##########################################
# Player number  152 :  Kessler Edwards
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  153 :  Boogie Ellis
# Error during the search phase
# ##########################################
# Player number  154 :  Keon Ellis
# Data successfully retrieved
# ##########################################
# Player number  155 :  Joel Embiid
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  156 :  Aaron Estrada
# Error during the search phase
# ##########################################
# Player number  157 :  Drew Eubanks
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  158 :  Tosan Evbuomwan
# Data successfully retrieved
# ##########################################
# Player number  159 :  Danté Exum
# Error during the search phase
# ##########################################
# Player number  160 :  Bruno Fernando
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  161 :  Max Fiedler
# Error during the search phase
# ##########################################
# Player number  162 :  Kyle Filipowski
# Data successfully retrieved
# ##########################################
# Player number  163 :  Dorian Finney-Smith
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  164 :  Adam Flagler
# Data successfully retrieved
# ##########################################
# Player number  165 :  Trentyn Flowers
# ##########################################
# Player number  166 :  Malachi Flynn
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  167 :  Simone Fontecchio
# Data successfully retrieved
# ##########################################
# Player number  168 :  De'Aaron Fox
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  169 :  Enrique Freeman
# Data successfully retrieved
# ##########################################
# Player number  170 :  Andrew Funk
# ##########################################
# Player number  171 :  Johnny Furphy
# Data successfully retrieved
# ##########################################
# Player number  172 :  Daniel Gafford
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  173 :  Darius Garland
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  174 :  Luka Garza
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  175 :  Keyonte George
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  176 :  Kyshawn George
# Data successfully retrieved
# ##########################################
# Player number  177 :  Paul George
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  178 :  Taj Gibson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  179 :  Josh Giddey
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  180 :  Harry Giles III
# Error during the search phase
# ##########################################
# Player number  181 :  Shai Gilgeous-Alexander
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  182 :  Anthony Gill
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  183 :  Collin Gillespie
# Data successfully retrieved
# ##########################################
# Player number  184 :  Jacob Gilyard
# Data successfully retrieved
# ##########################################
# Player number  185 :  Rudy Gobert
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  186 :  Jordan Goodwin
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  187 :  Aaron Gordon
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  188 :  Eric Gordon
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  189 :  Jazian Gortman
# Error during the search phase
# ##########################################
# Player number  190 :  Devonte' Graham
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  191 :  Jerami Grant
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  192 :  AJ Green
# Error during the search phase
# ##########################################
# Player number  193 :  Draymond Green
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  194 :  Jalen Green
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  195 :  Javonte Green
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  196 :  Jeff Green
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  197 :  Josh Green
# Error during the search phase
# ##########################################
# Player number  198 :  Quentin Grimes
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  199 :  Mouhamed Gueye
# ##########################################
# Player number  200 :  Rui Hachimura
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  201 :  Tyrese Haliburton
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  202 :  PJ Hall
# Error during the search phase
# ##########################################
# Player number  203 :  Tim Hardaway Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  204 :  James Harden
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  205 :  Jaden Hardy
# ##########################################
# Player number  206 :  Elijah Harkless
# Error during the search phase
# ##########################################
# Player number  207 :  Ron Harper Jr.
# Data successfully retrieved
# ##########################################
# Player number  208 :  Gary Harris
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  209 :  Kevon Harris
# ##########################################
# Player number  210 :  Tobias Harris
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  211 :  Josh Hart
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  212 :  Isaiah Hartenstein
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  213 :  Sam Hauser
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  214 :  Jordan Hawkins
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  215 :  Jaxson Hayes
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  216 :  Killian Hayes
# Data successfully retrieved
# ##########################################
# Player number  217 :  Scoot Henderson
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  218 :  Taylor Hendricks
# Data successfully retrieved
# ##########################################
# Player number  219 :  Tyler Herro
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  220 :  Buddy Hield
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  221 :  Haywood Highsmith
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  222 :  Malcolm Hill
# Data successfully retrieved
# ##########################################
# Player number  223 :  Blake Hinson
# Error during the search phase
# ##########################################
# Player number  224 :  Nate Hinton
# Error during the search phase
# ##########################################
# Player number  225 :  Aaron Holiday
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  226 :  Jrue Holiday
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  227 :  Ronald Holland II
# Error during the search phase
# ##########################################
# Player number  228 :  Richaun Holmes
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  229 :  DaRon Holmes II
# Data successfully retrieved
# ##########################################
# Player number  230 :  Chet Holmgren
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  231 :  Jalen Hood-Schifino
# Data successfully retrieved
# ##########################################
# Player number  232 :  Al Horford
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  233 :  Talen Horton-Tucker
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  234 :  Caleb Houstan
# Data successfully retrieved
# ##########################################
# Player number  235 :  Jett Howard
# Data successfully retrieved
# ##########################################
# Player number  236 :  Kevin Huerter
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  237 :  Jay Huff
# Data successfully retrieved
# ##########################################
# Player number  238 :  Ariel Hukporti
# ##########################################
# Player number  239 :  De'Andre Hunter
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  240 :  Bones Hyland
# Error during the search phase
# ##########################################
# Player number  241 :  Oso Ighodaro
# Data successfully retrieved
# ##########################################
# Player number  242 :  Joe Ingles
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  243 :  Brandon Ingram
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  244 :  Harrison Ingram
# Data successfully retrieved
# ##########################################
# Player number  245 :  Kyrie Irving
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  246 :  Jonathan Isaac
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  247 :  Jaden Ivey
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  248 :  GG Jackson
# Error during the search phase
# ##########################################
# Player number  249 :  Isaiah Jackson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  250 :  Quenton Jackson
# Data successfully retrieved
# ##########################################
# Player number  251 :  Reggie Jackson
# Error during the search phase
# ##########################################
# Player number  252 :  Andre Jackson Jr.
# Data successfully retrieved
# ##########################################
# Player number  253 :  Jaren Jackson Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  254 :  Trayce Jackson-Davis
# Data successfully retrieved
# ##########################################
# Player number  255 :  Bronny James
# Error during the search phase
# ##########################################
# Player number  256 :  LeBron James
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  257 :  Jaime Jaquez Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  258 :  DaQuan Jeffries
# Error during the search phase
# ##########################################
# Player number  259 :  Trey Jemison
# ##########################################
# Player number  260 :  Daniss Jenkins
# ##########################################
# Player number  261 :  Ty Jerome
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  262 :  Chase Jeter
# Error during the search phase
# ##########################################
# Player number  263 :  Isaiah Joe
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  264 :  AJ Johnson
# Error during the search phase
# ##########################################
# Player number  265 :  Cameron Johnson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  266 :  Jalen Johnson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  267 :  James Johnson
# Error during the search phase
# ##########################################
# Player number  268 :  Keldon Johnson
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  269 :  Keon Johnson
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  270 :  Keshad Johnson
# Data successfully retrieved
# ##########################################
# Player number  271 :  Keyontae Johnson
# Data successfully retrieved
# ##########################################
# Player number  272 :  Nikola Jokić
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  273 :  Colby Jones
# Data successfully retrieved
# ##########################################
# Player number  274 :  Dillon Jones
# Data successfully retrieved
# ##########################################
# Player number  275 :  Herbert Jones
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  276 :  Isaac Jones
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  277 :  Kai Jones
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  278 :  Mason Jones
# ##########################################
# Player number  279 :  Spencer Jones
# Error during the search phase
# ##########################################
# Player number  280 :  Tre Jones
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  281 :  Tyus Jones
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  282 :  Derrick Jones Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  283 :  DeAndre Jordan
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  284 :  Cory Joseph
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  285 :  Nikola Jović
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  286 :  Johnny Juzang
# Data successfully retrieved
# ##########################################
# Player number  287 :  Frank Kaminsky
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  288 :  Yuki Kawamura
# Error during the search phase
# ##########################################
# Player number  289 :  Kylor Kelley
# Error during the search phase
# ##########################################
# Player number  290 :  Luke Kennard
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  291 :  Walker Kessler
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  292 :  Braxton Key
# Data successfully retrieved
# ##########################################
# Player number  293 :  Corey Kispert
# Error during the search phase
# ##########################################
# Player number  294 :  Maxi Kleber
# Error during the search phase
# ##########################################
# Player number  295 :  Bobi Klintman
# Data successfully retrieved
# ##########################################
# Player number  296 :  Dalton Knecht
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  297 :  Kevin Knox II
# Error during the search phase
# ##########################################
# Player number  298 :  Tyler Kolek
# Data successfully retrieved
# ##########################################
# Player number  299 :  Christian Koloko
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  300 :  John Konchar
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  301 :  Luke Kornet
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  302 :  Vít Krejčí
# Data successfully retrieved
# ##########################################
# Player number  303 :  Jonathan Kuminga
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  304 :  Kyle Kuzma
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  305 :  Skal Labissiere
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  306 :  Jock Landale
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  307 :  Jake LaRavia
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  308 :  Pelle Larsson
# Data successfully retrieved
# ##########################################
# Player number  309 :  Zach LaVine
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  310 :  A.J. Lawson
# Error during the search phase
# ##########################################
# Player number  311 :  Damion Lee
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  312 :  Alex Len
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  313 :  Kawhi Leonard
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  314 :  Malevy Leons
# Error during the search phase
# ##########################################
# Player number  315 :  Caris LeVert
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  316 :  Maxwell Lewis
# Data successfully retrieved
# ##########################################
# Player number  317 :  E.J. Liddell
# Error during the search phase
# ##########################################
# Player number  318 :  Damian Lillard
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  319 :  Nassir Little
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  320 :  Dereck Lively II
# Data successfully retrieved
# ##########################################
# Player number  321 :  Chris Livingston
# ##########################################
# Player number  322 :  Kenneth Lofton Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  323 :  Kevon Looney
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  324 :  Brook Lopez
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  325 :  Kevin Love
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  326 :  Kyle Lowry
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  327 :  Seth Lundy
# Data successfully retrieved
# ##########################################
# Player number  328 :  Trey Lyles
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  329 :  Thon Maker
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  330 :  Sandro Mamukelashvili
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  331 :  Terance Mann
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  332 :  Tre Mann
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  333 :  Lauri Markkanen
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  334 :  Naji Marshall
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  335 :  Caleb Martin
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  336 :  Cody Martin
# Error during the search phase
# ##########################################
# Player number  337 :  Jaylen Martin
# ##########################################
# Player number  338 :  KJ Martin
# Error during the search phase
# ##########################################
# Player number  339 :  Tyrese Martin
# Data successfully retrieved
# ##########################################
# Player number  340 :  Garrison Mathews
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  341 :  Bennedict Mathurin
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  342 :  Karlo Matković
# ##########################################
# Player number  343 :  Tyrese Maxey
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  344 :  Skylar Mays
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  345 :  Miles McBride
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  346 :  Jared McCain
# Data successfully retrieved
# ##########################################
# Player number  347 :  Mac McClung
# Data successfully retrieved
# ##########################################
# Player number  348 :  CJ McCollum
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  349 :  T.J. McConnell
# Error during the search phase
# ##########################################
# Player number  350 :  Javante McCoy
# Error during the search phase
# ##########################################
# Player number  351 :  Kevin McCullar Jr.
# Data successfully retrieved
# ##########################################
# Player number  352 :  Jaden McDaniels
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  353 :  Jalen McDaniels
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  354 :  Bryce McGowens
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  355 :  Jordan McLaughlin
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  356 :  Jack McVeigh
# Data successfully retrieved
# ##########################################
# Player number  357 :  De'Anthony Melton
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  358 :  Nathan Mensah
# ...
# Data successfully retrieved
# ##########################################
# Player number  489 :  Jamarion Sharp
# Error during the search phase
# ##########################################
# Player number  490 :  Day'Ron Sharpe
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  491 :  Shaedon Sharpe
# Error during the search phase
# ##########################################
# Player number  492 :  Jamal Shead
# Data successfully retrieved
# ##########################################
# Player number  493 :  Ben Sheppard
# Data successfully retrieved
# ##########################################
# Player number  494 :  Reed Sheppard
# Data successfully retrieved
# ##########################################
# Player number  495 :  Pascal Siakam
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  496 :  Ben Simmons
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  497 :  Anfernee Simons
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  498 :  K.J. Simpson
# Error during the search phase
# ##########################################
# Player number  499 :  Jericho Sims
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  500 :  Dmytro Skapintsev
# Error during the search phase
# ##########################################
# Player number  501 :  Jalen Slawson
# ##########################################
# Player number  502 :  Marcus Smart
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  503 :  Dru Smith
# Data successfully retrieved
# ##########################################
# Player number  504 :  Jalen Smith
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  505 :  Tolu Smith
# Error during the search phase
# ##########################################
# Player number  506 :  Tyler Smith
# Error during the search phase
# ##########################################
# Player number  507 :  Zhaire Smith
# ##########################################
# Player number  508 :  Jabari Smith Jr.
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  509 :  Nick Smith Jr.
# Data successfully retrieved
# ##########################################
# Player number  510 :  Jeremy Sochan
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  511 :  Cam Spencer
# Data successfully retrieved
# ##########################################
# Player number  512 :  Pat Spencer
# Error during the search phase
# ##########################################
# Player number  513 :  Jaden Springer
# Data successfully retrieved
# ##########################################
# Player number  514 :  Isaiah Stevens
# Error during the search phase
# ##########################################
# Player number  515 :  Lamar Stevens
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  516 :  Erik Stevenson
# Error during the search phase
# ##########################################
# Player number  517 :  DJ Steward
# Data successfully retrieved
# ##########################################
# Player number  518 :  Isaiah Stewart
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  519 :  Julian Strawther
# Data successfully retrieved
# ##########################################
# Player number  520 :  Max Strus
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  521 :  Jalen Suggs
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  522 :  Cole Swider
# Data successfully retrieved
# ##########################################
# Player number  523 :  Jae'Sean Tate
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  524 :  Jayson Tatum
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  525 :  Terry Taylor
# Data successfully retrieved
# ##########################################
# Player number  526 :  Garrett Temple
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  527 :  Dalen Terry
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  528 :  Daniel Theis
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  529 :  Brodric Thomas
# ##########################################
# Player number  530 :  Cam Thomas
# Error during the search phase
# ##########################################
# Player number  531 :  Amen Thompson
# Error during the search phase
# ##########################################
# Player number  532 :  Ausar Thompson
# Data successfully retrieved
# ##########################################
# Player number  533 :  Ethan Thompson
# Error during the search phase
# ##########################################
# Player number  534 :  Klay Thompson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  535 :  Tristan Thompson
# Error during the search phase
# ##########################################
# Player number  536 :  JT Thor
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  537 :  Matisse Thybulle
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  538 :  Xavier Tillman
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  539 :  Nikola Topić
# ##########################################
# Player number  540 :  Jacob Toppin
# ##########################################
# Player number  541 :  Obi Toppin
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  542 :  Karl-Anthony Towns
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  543 :  Armel Traoré
# Error during the search phase
# ##########################################
# Player number  544 :  Luke Travers
# ##########################################
# Player number  545 :  Gary Trent Jr.
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  546 :  Oscar Tshiebwe
# Error while retrieving data
# Error while retrieving data
# Error while retrieving data
# Error while retrieving data
# ##########################################
# Player number  547 :  Jordan Tucker
# Data successfully retrieved
# ##########################################
# Player number  548 :  P.J. Tucker
# Error during the search phase
# ##########################################
# Player number  549 :  Myles Turner
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  550 :  Hunter Tyson
# Data successfully retrieved
# ##########################################
# Player number  551 :  Jaylon Tyson
# Data successfully retrieved
# ##########################################
# Player number  552 :  Stanley Umude
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  553 :  Jonas Valančiūnas
# Error during the search phase
# ##########################################
# Player number  554 :  Jarred Vanderbilt
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  555 :  Fred VanVleet
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  556 :  Devin Vassell
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  557 :  Gabe Vincent
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  558 :  Nikola Vučević
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  559 :  Tristan Vukcevic
# ##########################################
# Player number  560 :  Dean Wade
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  561 :  Franz Wagner
# Error during the search phase
# ##########################################
# Player number  562 :  Moritz Wagner
# Error during the search phase
# ##########################################
# Player number  563 :  Jabari Walker
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  564 :  Jarace Walker
# Data successfully retrieved
# ##########################################
# Player number  565 :  Lonnie Walker IV
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  566 :  Cason Wallace
# Data successfully retrieved
# ##########################################
# Player number  567 :  Keaton Wallace
# Data successfully retrieved
# ##########################################
# Player number  568 :  Jordan Walsh
# Data successfully retrieved
# ##########################################
# Player number  569 :  Ja'Kobe Walter
# Data successfully retrieved
# ##########################################
# Player number  570 :  Kel'el Ware
# Data successfully retrieved
# ##########################################
# Player number  571 :  T.J. Warren
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  572 :  P.J. Washington
# Error during the search phase
# ##########################################
# Player number  573 :  Warren Washington
# Error during the search phase
# ##########################################
# Player number  574 :  TyTy Washington Jr.
# Error during the search phase
# ##########################################
# Player number  575 :  Lindy Waters III
# Data successfully retrieved
# ##########################################
# Player number  576 :  Trendon Watford
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  577 :  Anton Watson
# Data successfully retrieved
# ##########################################
# Player number  578 :  Peyton Watson
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  579 :  Jaylen Wells
# Data successfully retrieved
# ##########################################
# Player number  580 :  Victor Wembanyama
# Data successfully retrieved
# ##########################################
# Player number  581 :  Blake Wesley
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  582 :  Russell Westbrook
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  583 :  Coby White
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  584 :  Derrick White
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  585 :  Dariq Whitehead
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  586 :  Cam Whitmore
# Data successfully retrieved
# ##########################################
# Player number  587 :  Aaron Wiggins
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  588 :  Andrew Wiggins
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  589 :  Alondes Williams
# Data successfully retrieved
# ##########################################
# Player number  590 :  Brandon Williams
# Error during the search phase
# ##########################################
# Player number  591 :  Cody Williams
# Data successfully retrieved
# ##########################################
# Player number  592 :  Grant Williams
# Error during the search phase
# ##########################################
# Player number  593 :  Jalen Williams
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  594 :  Jaylin Williams
# ##########################################
# Player number  595 :  Kenrich Williams
# Data successfully retrieved
# ##########################################
# Player number  596 :  Mark Williams
# Error during the search phase
# ##########################################
# Player number  597 :  Nate Williams
# Error during the search phase
# ##########################################
# Player number  598 :  Patrick Williams
# Error during the search phase
# ##########################################
# Player number  599 :  Ziaire Williams
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  600 :  Robert Williams III
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  601 :  Vince Williams Jr.
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  602 :  Zion Williamson
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  603 :  Jalen Wilson
# Data successfully retrieved
# ##########################################
# Player number  604 :  James Wiseman
# Error during the search phase
# ##########################################
# Player number  605 :  Christian Wood
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  606 :  Moses Wood
# Error during the search phase
# ##########################################
# Player number  607 :  Delon Wright
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  608 :  Guerschon Yabusele
# Error during the search phase
# ##########################################
# Player number  609 :  Cui Yongxi
# Error during the search phase
# ##########################################
# Player number  610 :  Trae Young
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  611 :  Cody Zeller
# Data successfully retrieved
# Data successfully retrieved
# Data successfully retrieved
# ##########################################
# Player number  612 :  Ivica Zubac
# Data successfully retrieved
# Data successfully retrieved
# ##########################################

# %%
file_name="NBA Players' Performances.json"
with open(file_name,'w') as json_file:
    json.dump(player_data_dict,json_file)
